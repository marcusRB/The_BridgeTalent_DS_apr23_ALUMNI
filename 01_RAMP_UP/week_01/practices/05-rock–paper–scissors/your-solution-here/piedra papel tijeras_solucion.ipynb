# %% [markdown]
# # Piedra, papel, tijeras
#
# Vamos jugar contra nuestro ordenador al famoso juego.
#
# https://es.wikipedia.org/wiki/Piedra,_papel_o_tijera
#
# Se aconseja el uso de funciones

# %%
# Importa la función choice del módulo random
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

# Asigna a una lista las 3 posibles opciones: 'piedra', 'papel' o 'tijeras'.
 
opciones=["piedra","papel","tijera"]                  

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...

partidas=10
jugador=0
maquina=0
empate=0

# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función del número de partidas máximas

partidas_ganador=int((partidas/2)+1)

# %%
# Define una función que devuelva aleatoriamente una de las 3 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 

def opcion_maquina(x):
 # i recibe aleatorio entre 0 y len(x)
 return random.choice(x)

# %%
# Define una función que pregunte tu elección: 'piedra', 'papel' o 'tijeras'
# sólo debe permitir una de las 3 opciones. Esto es programación defensiva. 
# Si no es piedra, papel o tijeras sigue preguntando hasta que lo sea. 

#Recibe una lista de valores como parámetro.
#La muestra, devuelve la opción elegida por el usuario o false si se elige un valor incorrecto

def opcion_jugador(x): 
 a=""
 #muestra las opciones a elegir
 while a!="1" and  a!="2" and a!="3":
    print("Elige opción (número):")
    i=0
    while i<(len(x)):
     print(f"{i+1}. {x[i]}")
     i+=1
    a=input()
    print(f"{a}\n")
 #print(f"Opción elegida: {x[int(a)-1]}")
 return (x[int(a)-1])

# %%
# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano 
def jugar(a,b):
  global jugador
  global maquina
  global empate
  print(f"Opción jugador: {a}")
  print(f"Opción máquina: {b}")
  if a==b: 
    empate=empate+1 
    print("empate")
  elif a=="piedra" and b=="tijera": 
    jugador=jugador+1
    print("gana jugador")
  elif a=="tijera" and b=="papel":
    jugador+=1
    print("gana jugador")
  elif a=="papel" and b=="piedra":
    jugador+=1
    print("gana jugador")
  elif b=="piedra" and a=="tijera": 
    maquina=maquina+1
    print("gana maquina")
  elif b=="tijera" and a=="papel":
    maquina+=1
    print("gana maquina")
  elif b=="papel" and a=="piedra":
    maquina+=1
    print("gana maquina")
### definir ganadores de cada partida según valores introducidos

# %%
def ganador(j,m,e):
    print("\n\n")
    print("__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*")
    if j>m: print(f"\t\tGanador: Jugador {j} a {m}\t\tempate: {e}")
    elif m>j: print(f"\t\tGanador: Máquina {m} a {j}\t\tempate: {e}")
    else: print(f"Empate a {j} victorias\t\t empate: {e}")
    print("__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*")

# %%
# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados
# Crea dos variables que acumulen las partidas ganadas de cada participante


# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 


def ppt(partidas): #piedra papel tijera 
 op_j=""
 op_m=""
 num_jugadas=0
 print("****\t\tPIEDRA-PAPEL-TIJERA\t\t****")
 print("\n")
 while num_jugadas<partidas and jugador<=partidas_ganador and maquina<partidas_ganador:  
   #si no se ha alcanzado el nùmero de jugadas, o el jugador/máquina no han alcanzado el mínimo de victorias, se juega
   op_j=opcion_jugador(opciones)
   op_m=opcion_maquina(opciones)
   num_jugadas+=1     
   print(f"Partida: {num_jugadas} (Al mejor de {partidas})")
   jugar(op_j,op_m)
   
   print("\n")
   print("************************************************************")
   print(f"Partidas Totales: {num_jugadas}")
   print(f"Jugador: {jugador}\t\tMáquina: {maquina}\t\tEmpate: {empate}")
   print("************************************************************")
   print("\n")
   
 ganador(jugador,maquina,empate)

# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados
# Crea dos variables que acumulen las partidas ganadas de cada participante


# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 

    
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# acumuladas

# %%
ppt(partidas)
 #reinicar contadores
jugador=0
maquina=0
empate=0

# %% [markdown]
# # Bonus: Piedra, papel, tijeras, lagarto, spock
#
# Ahora vienen las mejoras.
#
# http://www.samkass.com/theories/RPSSL.html
#
# Se te pide que implimentes unas mejoras con respecto al simple juego previo. Además el número de partidas (que deberá ser IMPAR) se pedirá por consola hasta que se introduzca un número válido.
#
# Mejoras:
# * 5 opciones: piedra, papel, tijeras, lagarto, spock
# * El número de partidas se pide por consola
# Consejo: Reutiliza código que ya hagas utilizado

# %%
# Importa la función choice del módulo random

import random

# Define una función que pide por teclado un número impar, hasta que no sea válido
# seguirá pidiendo

def jugadas():
 a=0
 while a%2==0:
  try:
   a=int(input("ELIGE NÚMERO DE JUGADAS (impar)"))
  except ValueError:
    print("No es un número impar")
    a=0
 return(a)
 

jugador=0
maquina=0
empate=0


# Asigna a una lista las 5 posibles opciones. 
opciones=["piedra","papel","tijera", "lagarto","spock"]

# Asigna una variable al número de partidas máxima: 1, 3, 5, etc...
# Esta vez se usa la función definida previamente

# Asigna una variable al número de partidas que debe ganar un jugador para ganar. 
# Preferiblemente el valor será en función de el número de partidas máximas

# Define una función que devuelva aleatoriamente una de las 5 opciones. 
# Esto corresponderá a la jugada de la máquina. Totalmente aleatoria. 

def opcion_maquina(x):
 # x lista de opciones
 # recibe aleatorio entre 0 y len(x) 
 return random.choice(x)


# Define una función que pregunte tu elección de entre las 5
# sólo debe permitir una de las 5 opciones. Esto es programación defensiva. 
# Si no es válida sigue preguntando hasta que lo sea. 

def opcion_jugador(x):  #x lista de opciones
 a=""
 #muestra las opciones a elegir
 while a not in ("1","2","3","4","5"):
    print("Elige opción (número):")
    i=0
    while i<(len(x)):
     print(f"{i+1}. {x[i]}")
     i+=1
    a=input()
    print(f"{a}\n")
 #print(f"Opción elegida: {x[int(a)-1]}")
 return (x[int(a)-1])


# Define una función que resuelva un combate. 
# Devuelve 0 si hay empate, 1 si gana la máquina, 2 si gana el jugador humano
# Ahora hay más opciones

def jugar(a,b):
  global jugador
  global maquina
  global empate

# piedra gana	tijera lagarto
# papel gana	piedra spock
# tijera gana	papel lagarto
# spock gana	tijera piedra
# lagarto gana	spock papel

  print(f"Opción jugador: {a}")
  print(f"Opción máquina: {b}")
  if a==b: 
    empate=empate+1 
    print("empate")
  elif a=="piedra" and b=="tijera": 
    jugador+=1
    print("gana jugador")
  elif a=="piedra" and b=="lagarto": 
    jugador+=1
    print("gana jugador")
  elif a=="tijera" and b=="papel":
    jugador+=1
    print("gana jugador")
  elif a=="tijera" and b=="lagarto":
    jugador+=1
    print("gana jugador")
  elif a=="papel" and b=="piedra":
    jugador+=1
    print("gana jugador")
  elif a=="papel" and b=="spock":
    jugador+=1
    print("gana jugador")
  elif a=="spock" and b=="piedra":
    jugador+=1
    print("gana jugador")
  elif a=="spock" and b=="tijera":
    jugador+=1
    print("gana jugador")
  elif b=="piedra" and a=="tijera": 
    maquina+=1
    print("gana máquina")
  elif b=="piedra" and a=="lagarto": 
    maquina+=1
    print("gana máquina")
  elif b=="tijera" and b=="papel":
    maquina+=1
    print("gana máquina")
  elif b=="tijera" and a=="lagarto":
    maquina+=1
    print("gana máquina")
  elif b=="papel" and a=="piedra":
    maquina+=1
    print("gana máquina")
  elif b=="papel" and a=="spock":
    maquina+=1
    print("gana máquina")
  elif b=="spock" and a=="piedra":
    maquina+=1
    print("gana máquina")
  elif b=="spock" and a=="tijera":
    maquina+=1
    print("gana máquina")
    
    
# Define una función que muestre la elección de cada jugador y el estado de la partida
# Esta función debe utilizarse cada vez que se actualicen los puntos acumulados

def ganador(j,m,e):
    print("\n\n")
    print("__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*")
    if j>m: print(f"\t\tGanador: Jugador {j} a {m}\t\tempate: {e}")
    elif m>j: print(f"\t\tGanador: Máquina {m} a {j}\t\tempate: {e}")
    else: print(f"Empate a {j} victorias\t\t empate: {e}")
    print("__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*")
    
# Crea dos variables que acumulen las partidas ganadas de cada participante
# Crea un bucle que itere mientras ningún jugador alcance el mínimo de victorias
# necesarias para ganar. Dentro del bucle resuelve la jugada de la
# máquina y pregunta la del jugador. Comparalas y actualiza el valor de las variables
# que acumulen las partidas ganadas de cada participante. 

def pptls(): #piedra papel tijera lagarto spock
 global jugador
 global maquina
 global empate
 
 partidas=jugadas()
 partidas_ganador=int((partidas/2)+1)
 
 op_j=""
 op_m=""
 num_jugadas=0
 print("****\t\tPIEDRA-PAPEL-TIJERA-LAGARTO-SPOCK\t\t****")
 print("\n")
 while num_jugadas<partidas and jugador<=partidas_ganador and maquina<partidas_ganador:  
   #si no se ha alcanzado el nùmero de jugadas, o el jugador/máquina no han alcanzado el mínimo de victorias, se juega
   op_j=opcion_jugador(opciones)
   op_m=opcion_maquina(opciones)
   num_jugadas+=1     
   print(f"Partida: {num_jugadas} (Al mejor de {partidas})")
   jugar(op_j,op_m)
   
   print("\n")
   print("************************************************************")
   print(f"Partidas Totales: {num_jugadas}")
   print(f"Jugador: {jugador}\t\tMáquina: {maquina}\t\tEmpate: {empate}")
   print("************************************************************")
   print("\n")
   
 ganador(jugador,maquina,empate)
 #reinicializar variables
 jugador=0
 maquina=0
 empate=0
    
# Anuncia por consola el ganador del juego en función de quién tiene más victorias 
# aculumadas

pptls()
# Out:
# No es un número impar
# No es un número impar
# No es un número impar
# ****		PIEDRA-PAPEL-TIJERA-LAGARTO-SPOCK		****
#
#
# Elige opción (número):
# 1. piedra
# 2. papel
# 3. tijera
# 4. lagarto
# 5. spock
# 5
#
# Partida: 1 (Al mejor de 5)
# Opción jugador: spock
# Opción máquina: papel
# gana máquina
#
#
# ************************************************************
# Partidas Totales: 1
# Jugador: 0		Máquina: 1		Empate: 0
# ************************************************************
#
#
# Elige opción (número):
# 1. piedra
# 2. papel
# 3. tijera
# 4. lagarto
# 5. spock
# 5
#
# Partida: 2 (Al mejor de 5)
# Opción jugador: spock
# Opción máquina: tijera
# gana jugador
#
#
# ************************************************************
# Partidas Totales: 2
# Jugador: 1		Máquina: 1		Empate: 0
# ************************************************************
#
#
# Elige opción (número):
# 1. piedra
# 2. papel
# 3. tijera
# 4. lagarto
# 5. spock
# 1
#
# Partida: 3 (Al mejor de 5)
# Opción jugador: piedra
# Opción máquina: tijera
# gana jugador
#
#
# ************************************************************
# Partidas Totales: 3
# Jugador: 2		Máquina: 1		Empate: 0
# ************************************************************
#
#
# Elige opción (número):
# 1. piedra
# 2. papel
# 3. tijera
# 4. lagarto
# 5. spock
# 1
#
# Partida: 4 (Al mejor de 5)
# Opción jugador: piedra
# Opción máquina: lagarto
# gana jugador
#
#
# ************************************************************
# Partidas Totales: 4
# Jugador: 3		Máquina: 1		Empate: 0
# ************************************************************
#
#
# Elige opción (número):
# 1. piedra
# 2. papel
# 3. tijera
# 4. lagarto
# 5. spock
# 2
#
# Partida: 5 (Al mejor de 5)
# Opción jugador: papel
# Opción máquina: spock
# gana jugador
#
#
# ************************************************************
# Partidas Totales: 5
# Jugador: 4		Máquina: 1		Empate: 0
# ************************************************************
#
#
#
#
#
# __*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*
# 		Ganador: Jugador 4 a 1		empate: 0
# __*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*__*-*

# %% [markdown]
# Si has programado con cabeza, el bonus son simples modificaciones al juego original.

# %% [markdown]
# ## Objetivos
# 1. Uso de bucle
# 2. Captura de datos por consola
# 3. Uso if-elif-else
# 4. Uso de try-except
# 5. Definición de funciones. Programación modular.
# 6. Operadores lógicos.
# 7. Imprimir por consola
# 8. Importación de módulos externos
